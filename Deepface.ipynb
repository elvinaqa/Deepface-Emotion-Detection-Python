# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()

# %%
# im = Image.open(BytesIO(uploaded['theCorona.PNG']))
img = cv2.imread("theCorona.PNG")
plt.imshow(img[:,:, ::-1])
plt.show()

# %%
result = DeepFace.analyze(img, actions=['emotion'])

print(result['emotion'], result['dominant_emotion'])
# Out:
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Finding actions:   0%|          | 0/1 [00:00<?, ?it/s]
# Action: emotion:   0%|          | 0/1 [00:00<?, ?it/s]
# Actions to do:  ['emotion']
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# {'angry': 0.29074407648295164, 'disgust': 5.0829684905551176e-08, 'fear': 0.7240448147058487, 'happy': 4.734936851491511e-05, 'sad': 32.75463879108429, 'surprise': 1.7963841969503846e-05, 'neutral': 66.23050570487976} neutral
